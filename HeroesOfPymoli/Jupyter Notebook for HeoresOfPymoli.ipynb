# %%
import os
import pandas as pd

game_df = pd.read_csv('purchase_data.csv')
game_df.head(10)
# Out:
#    Purchase ID             SN  Age                 Gender  Item ID  \
# 0            0        Lisim78   20                   Male      108
# 1            1    Lisovynya38   40                   Male      143
# 2            2     Ithergue48   24                   Male       92
# 3            3  Chamassasya86   24                   Male      100
# 4            4      Iskosia90   23                   Male      131
# 5            5        Yalae81   22                   Male       81
# 6            6      Itheria73   36                   Male      169
# 7            7    Iskjaskst81   20                   Male      162
# 8            8      Undjask33   22                   Male       21
# 9            9    Chanosian48   35  Other / Non-Disclosed      136
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# ...

# %%
#The total number of players
total_players = len(game_df['SN'].unique())
print("Total players:", total_players)
# Out:
# Total players: 576

# %%
#total of all item names
item_names_count = len(game_df['Item Name'].unique())

#finding average purchase price
ave_price = game_df['Price'].mean()

#total number of purchases
total_purchases = len(game_df['Price'])

#total purchases
total_revenue = game_df['Price'].sum()

# All of the data found in summary
summary_df = pd.DataFrame({"Total Unique Items": item_names_count,
                              "Average Price of Purchase": ave_price,
                              "Total Number of Purchases": total_purchases,
                              "Total Revenue": total_revenue}, index=[0])
summary_df
# Out:
#    Total Unique Items  Average Price of Purchase  Total Number of Purchases  \
# 0                 179                   3.050987                        780
#
#    Total Revenue
# 0        2379.77

# %%
#Count of male and female players
game_df['Gender'].value_counts(ascending=False)
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
gender_df = pd.DataFrame({"Male": [652/780, 652], "Female": [113/780, 113], "Other / Non-Disclosed": [15/780, 15]}, index=["Percentage of Players","Total Count"])
gender_df.style.set_precision(3)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_c81e6f70_0b0a_11eb_8a45_acde48001122" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Male</th>
#         <th class="col_heading level0 col1" >Female</th>
#         <th class="col_heading level0 col2" >Other / Non-Disclosed</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c81e6f70_0b0a_11eb_8a45_acde48001122level0_row0" class="row_heading level0 row0" >Percentage of Players</th>
#         <td id="T_c81e6f70_0b0a_11eb_8a45_acde48001122row0_col0" class="data row0 col0" >0.836</td>
#         <td id="T_c81e6f70_0b0a_11eb_8a45_acde48001122row0_col1" class="data row0 col1" >0.145</td>
#         <td id="T_c81e6f70_0b0a_11eb_8a45_acde48001122row0_col2" class="data row0 col2" >0.0192</td>
#     </tr>    <tr>
#         <th id="T_c81e6f70_0b0a_11eb_8a45_acde48001122level0_row1" class="row_heading level0 row1" >Total Count</th>
# ...

# %%
#Dont forget about this one

gender_grouped = game_df.groupby(['Gender'])

gender_count = gender_grouped['Purchase ID'].count()

price_gender = gender_grouped['Price'].mean()

total_purchase_gender = gender_grouped['Price'].sum()

#ave_total_purchase = total_purchase_gender

# %%
bins = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

df_labels = ['<10', '10-14','15-19','20-24','25-29','30-34','35-39','40-44','45-49']

new_game = pd.cut(game_df['Age'], bins, labels=df_labels)

game_df['Age Range'] = pd.cut(game_df['Age'], bins, labels=df_labels)
game_df
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
#groupby item ID and then sort them
purchase_value = game_df.groupby(['Item ID'])
